# %% [markdown]
# # Google Colaboratory
# *  Google Colaboratory（本講義では，Colaboratory または Colab と呼ぶこともある）は，クラウド上で Pythonのプログラミング環境（細かく言うと [Jupyter Notebook](https://jupyter.org/) 環境）を提供する Google のウェブサービスの一つ
# *  ブラウザとGoogleのアカウントがあれば，制限はあるが誰でも無料で利用できる
# *  本講義では，[Google Chrome](https://www.google.com/intl/ja_jp/chrome/) をブラウザとして利用する
# *  Colab は「ノートブック」と呼ばれるファイルを使ってプログラミングを行う

# %% [markdown]
# ## ノートブックの基本構成
# ![ノートブック名](./fig/01_notebook_name.png)
#
# *  ノートブックの左上方（上図の赤枠部）には，ノートブック名が表示されている
# *  ノートブック名は任意の名前に変更することができる
# *  ノートブック名の下には「ファイル」や「編集」などのメニューがある
# *  さらに，その下には「+ コード」と「+ テキスト」というボタンがある
# *  ノートブックを実習で使用する場合は，「ドライブにコピー」をクリックして，ノートブックの複製を作成する

# %% [markdown]
# ## セルの基本操作
# * ノートブックは複数の「セル」と呼ばれるブロックで構成される
# * セルには「コードセル」と「テキストセル」の2種類がある
# * セルの上のどこかをクリックすると，そのセルを選択することができる
# * コードセルには，Pythonでコードを記述する
# * テキストセルには，一般の文書（テキスト，見出し，箇条書き等）が記述できる
# * テキストセルの上をダブルクリックすると，そのテキストセルの内容が編集可能となる
# * セルの追加はノートブック上部の[＋コード]と[＋テキスト]をクリック
# * セルの削除は，削除するセルを選択してから，ごみ箱アイコンをクリック
# * セル内のテキストの編集において，よく使うショートカットキーには，以下のようなものがある
#   * `[Ctrl] + [C]`: テキストのコピー
#   * `[Ctrl] + [X]`: テキストの切り取り
#   * `[Ctrl] + [V]`: テキストの貼り付け
#   * `[Ctrl] + [Z]`: 元に戻す

# %% [markdown]
# ## コードの実行
# *   コードセルに記述したPythonのコードは， `[Ctrl] + [Enter]` で実行できる（他のやり方もあるので自分で調べてみる or 試してみる）
# *   試しに以下のコードを実行してみる
# *   コードの意味については後述（今は気にしなくてよい）

# %%
print("Hello World!")

# %% [markdown]
# ## ノートブックの保存
# *  ノートブックは，`[Ctrl] + [S]` で手動保存できる
# *  なお，ノートブックは適当なタイミングで自動保存される
# *  メニューの右に「すべての変更を保存しました」と表示されていれば，現在の状態が保存されているので，手動保存する必要はない

# %% [markdown]
# ## ノートブックの設定
# ![設定1](./fig/01_notebook_setting1.png)
#
# *  ノートブック右上の歯車アイコン（上図赤枠部）をクリックすると，ノートブックの設定画面が表示される
# *  「エディタ」の設定を以下のようにしておく（下図参照）
# >*  **「インデント幅（スペース）」を「4」にする**
# >*  **「縦の罫線列」を「120」にする**
# >*  **「行番号を表示」にチェックを入れる**
# >*  **「インデントガイドの表示」にチェックを入れる**
# *  他の設定は任意（特に変更しなくてよい）
# *  設定が完了したら「保存」をクリックする
#
# ![設定2](./fig/01_notebook_setting2.png)

# %% [markdown]
# # コンピュータ実習（１）

# %% [markdown]
# ## 文字と数
# * コンピュータは情報を意味を持たない単なる数（データ）として扱う
# * ここでは，文字が数（データ）として扱われていることを確認する
# * 以下のコードを実行して結果を確認する
#   * `ord("文字")`： 指定した文字に対応する数（データ）を調べる
#   * `chr(数)`： 指定した数に対応する文字を調べる
# * 一つ一つの文字が区別できるように，別々の数が割り当てられている

# %%
ord("A")

# %%
ord("あ")

# %%
chr(65)

# %% [markdown]
# ## 実習：文字⇒数
# * 以下のコードセルに，文字「B」に対応する数を出力するコードを作成し，実行せよ

# %% [markdown]
# ## 実習：数⇒文字
# * 以下のコードセルに，「66」に対応する文字を出力するコードを作成し，実行せよ

# %% [markdown]
# ## 数の種類
# * コンピュータで扱う数には様々な種類（整数や小数など）がある
# * ここでは，人間にとって同じに見える「123」と「123.0」が，コンピュータ内部では違う種類の数として扱われていることを確認する
# * 以下のコードを実行して結果を確認する
#   * `type(数)`： 指定した数が，どの種類に属しているかを調べる
#   * **int**: integer（整数）の略で，整数として扱われていることを意味する
#   * **float**: floating point（浮動小数点数） の略で，小数（実数）として扱われていることを意味する
#   * 「123」と「123.0」違いは，単に「見た目の違い」ではなく，内部での表現方法や計算方法が違うことを意味する（詳細は次回以降）

# %%
type(123)

# %%
type(123.0)

# %% [markdown]
# # コンピュータ実習（２）

# %% [markdown]
# ## 10進数から2進数 / 16進数への基数変換
# * ここでは，10進数の整数から2進数の整数への基数変換を行う
# * 以下のコードを実行して結果を確認する
#   * `bin(10進数)`：指定した数を2進数で表現
#     * 先頭の「0b」は，2進数であることを意味する
#     * 0b以降が実際の2進数
#   * `hex(10進数)`：指定した数を16進数で表現
#     * 先頭の「0x」は，16進数であることを意味する
#     * 0x以降が実際の16進数

# %%
bin(11)

# %%
hex(732)

# %% [markdown]
# ## 実習：10進数⇒2進数
# * 以下のコードセルに，10進数「255」を 2進数に基数変換した結果を出力するコードを作成し，実行せよ

# %% [markdown]
# ## 実習：10進数⇒16進数
# * 以下のコードセルに，10進数「255」を 16進数に基数変換した結果を出力するコードを作成し，実行せよ

# %% [markdown]
# ## 16進数の役割
# * 人間は数値を10進数で理解し，コンピュータは2進数で理解する
# * 2進数は桁数が大きくなる（長くなる） ⇒ 見にくい（人間視点）
# * 16進数は，人間が長い2進数を見やすくする（短くする）ために使われる
# * コンピュータが16進数を扱うことはない（2進数のみを扱う）
#
# | 10進数 | 2進数 | 16進数 |
# |------|------|------|
# | 0  | 0000 | 0 |
# | 1  | 0001 | 1 |
# | 2  | 0010 | 2 |
# | 3  | 0011 | 3 |
# | 4  | 0100 | 4 |
# | 5  | 0101 | 5 |
# | 6  | 0110 | 6 |
# | 7  | 0111 | 7 |
# | 8  | 1000 | 8 |
# | 9  | 1001 | 9 |
# | 10 | 1010 | a |
# | 11 | 1011 | b |
# | 12 | 1100 | c |
# | 13 | 1101 | d |
# | 14 | 1110 | e |
# | 15 | 1111 | f |

# %% [markdown]
# ## 2進数 / 16進数から10進数への基数変換
# * 次に，2進数 / 16進数の整数から」10進数の整数への基数変換を行う
# * 具体的には，前の実習の逆の変換を行う
# * 以下のコードを実行して結果を確認する
#   * `bint("𝒑進数", 𝒑)`: 指定した基数𝑝の数（𝑝進数）を10進数で表現

# %%
int("1011", 2)

# %%
int("2dc", 16)

# %% [markdown]
# ## 実習：2進数⇒10進数
# * 以下のコードセルに，2進数「11111111」を 10進数に基数変換した結果を出力するコードを作成し，実行せよ

# %% [markdown]
# ## 実習：16進数⇒10進数
# * 以下のコードセルに，16進数「ff」を 10進数に基数変換した結果を出力するコードを作成し，実行せよ
