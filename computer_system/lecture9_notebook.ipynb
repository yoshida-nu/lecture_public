# %% [markdown]
# # 実習に必要なファイルのダウンロード
# * 実習を始める前に，必ず以下の2つのコードを順番に実行する
# * 2つ目のコードは実行しても何も出力されない（エラーが出なければ問題ない）
# * コードの意味や出力は理解しなくてよい（実習を行うための事前準備とだけ理解していればよい）
# * 実行するとノートブック上に，ファイル「lecture9_tools.py」が保存される
# * 2つ目のコードの「lecture9_tools」の下に赤い波線が表示されるかもしれないが，正常に実行できていれば問題ないので気にしなくてよい

# %%
# !curl -L -o lecture9_tools.py https://raw.githubusercontent.com/yoshida-nu/lecture_public/refs/heads/main/computer_system/lecture9_tools.py

# %%
from lecture9_tools import *

# %% [markdown]
# # コンピュータ実習（１）

# %% [markdown]
# ## 伝送効率の計算
# * 以下のコードで，伝送効率（＝［伝送速度］÷［回線速度］）を計算する
# * `transmission_efficiency(transmission_speed, line_speed)`:
#   * `transmission_speed`: 伝送速度 [Mbps]
#   * `line_speed`: 回線速度 [Mbps]

# %%
transmission_efficiency(2, 4)

# %% [markdown]
# ### 実習
# * 以下のコードセルに，伝送速度が 3Mbpsで，回線速度が 5Mbpsのときの伝送効率（単位は「％」）を出力するコードを作成し，実行せよ

# %%
transmission_efficiency(3, 5)

# %% [markdown]
# ## 伝送時間の計算
# * 以下のコードで，伝送時間を計算する
#   * ［伝送速度］＝（［伝送効率］÷100）×［回線速度］
#   * ［伝送時間］＝［データ量］÷［伝送速度］
# * `transmission_time(line_speed, efficiency, data_size)`:
#   * `line_speed`: 回線速度 [Mbps]
#   * `efficiency`: 伝送効率 [%]
#   * `data_size`: データ量 [MB]

# %%
transmission_time(1.5, 50, 12)

# %% [markdown]
# ### 実習
# * 以下のコードセルに，回線速度が 1.6 Mbps の伝送路を用いて，60 MB のデータを転送するのに必要な伝送時間（秒）を出力するコードを作成し，実行せよ
# * ここで，伝送路の伝送効率を 75 % とする

# %%
transmission_time(1.6, 75, 60)
