# %% [markdown]
# # 配列
# * Pythonで配列を扱う場合は「リスト」を用いる
# * Pythonの「リスト」と「連結リスト」は異なる意味を持つので注意する
# * リストは角括弧 `[ ]` を使って定義 ⇒ `リスト名＝[要素0, 要素1, 要素2, ...]`
# * 要素番号は0から開始することに注意
#
# <img src="./fig/pyhon_list.jpg" width="550">

# %%
score = [74, 68, 92, 59, 77] 
print(score[0])

# %% [markdown]
# ## 実習
# * 以下のコードセルに，上のコードと同じリスト`score = [74, 68, 92, 59, 77]`の3番目の要素「92」を出力するコードを作成し，実行せよ

# %% [markdown]
# # 繰り返し

# %% [markdown]
# ## for文による繰り返し
# *  `for`の直後に半角スペースを入れたあと，繰り返しの処理の中で用いる変数を記述
# *  その変数の直後に半角スペースを入れたあと，`in`と記述
# *  `in`の直後に半角スペースを入れたあと，特定の範囲の数値を指定できる`range`やリストを記述し，最後にコロン`:`を入れる
# *  各繰り返しで，`in`の直後で指定した`range`やリストの要素が順番に1つずつ変数に格納される
# *  取り出す要素がなくなったら繰り返しを終了する
# *  `range`の基本形： `range(開始番号, 終了番号+1)`
# *  `range`の例：
# >* `range(1, 6)` ⇒ `1, 2, 3, 4, 5`
# >* `range(3, 7)` ⇒ `3, 4, 5, 6`
#
# ---
# 書式:
# ```python
# for 変数 in rangeやリスト:
# 	処理
# ```
# ---
#
# * 擬似言語との違いに注意する
# * Pythonでは...
# >* 制御記述の後にコロン「`:`」を付ける
# >* 「`endfor`」は記述しない
#
# <img src="./fig/pseudolanguage_vs_python_for.jpg" width="500">

# %% [markdown]
# ### 繰り返しのコード例 その1
# * 「`i in range(a, b)`」の意味 ⇒「`i` を `a` から `b-1` まで `1` ずつ増やす」
# * 「`i, end=" "`」の意味 ⇒「`i` のうしろに空白を入れる」
#
# <img src="./fig/python_code_sample_for1.jpg" width="180">

# %%
for i in range(1, 6):
	print(i, end=" ")

# %% [markdown]
# ### 繰り返しのコード例 その2
# <img src="./fig/python_code_sample_for2.jpg" width="350">

# %%
score = [65, 82, 73, 91, 76]
for i in range(0, 5):
	print(score[i], end=" ")

# %% [markdown]
# * 以下のコードにしても，実行結果は同じ

# %%
score = [65, 82, 73, 91, 76]
for i in score:
	print(i, end=" ")

# %% [markdown]
# ## `while`文を使った繰り返し
# * `while`の直後に半角スペースを入れたあと，繰り返し処理の条件式を記述して，最後にコロン`:`を入れる
# * 条件式のデータ型は`if`文と同様にboolとなる
# * 条件式が `True`（真） である間，`while`ブロック内の処理を繰り返す
# * ブロックの意味は`if`文と同じ
# * 条件式が `False`（偽）になったら繰り返しが終わる ⇒ `while`ブロック直後の処理へ
#
# <img src="./fig/while.png" width="170">
#
# ---
# 書式:
# ```python
# while 条件式:
# 	処理
# ```
# ---
#
# * 擬似言語との違いに注意する
# * Pythonでは...
#   * 制御記述の後にコロン「`:`」を付ける
#   * 「`endwhile`」は記述しない
#   * `do`～`while`の構造はない
#
# <img src="./fig/pseudolanguage_vs_python_while.jpg" width="500">

# %% [markdown]
# ## 実習
# * 以下のコードセルに，次のフローチャートの処理をするコードを作成し，実行せよ
#
#   <img src="./fig/python_code_sample_for3.jpg" width="180">

# %% [markdown]
# # 関数
# * 関数を使うことで，複数行の処理をひとまとめにすることができる⇒コードが読みやすくなる
# * Pythonにはあらかじめ様々な関数が用意されている⇒組み込み関数と呼ぶ
# * 組み込み関数の例: `print` や `type` など
# * 関数は自分で自由に作る（定義する）ことができる

# %% [markdown]
# ## 関数に関する用語の定義
# * 関数に引き渡すデータのことを**引数**と呼ぶ
# * 関数を使うことを**呼び出す**という
# * 関数が返す値（出力）を**戻り値**と呼ぶ
#
# 戻り値はデータなので変数に格納することができる．

# %% [markdown]
# ## 引数と戻り値が共にない関数
# 引数がない関数を呼び出すときは，括弧`()`内に何も記述しない．
# ただし，括弧`()`は必ず記述する．
#
# <img src="./fig/pseudolanguage_vs_python_function1.jpg" width="500">

# %%
def say_hello():
    print("こんにちは")

say_hello()

# %% [markdown]
# ## 引数がない（戻り値だけある）関数
# <img src="./fig/pseudolanguage_vs_python_function2.jpg" width="500">

# %%
def say_hello():
    return "こんにちは"

result = say_hello()
print(result)

# %% [markdown]
# ## 戻り値がない（引数だけある）関数
# <img src="./fig/pseudolanguage_vs_python_function3.jpg" width="500">

# %%
def calc_sum(x, y):
    print(x + y)

calc_sum(1, 2)

# %% [markdown]
# ## 引数も戻り値もある関数
# <img src="./fig/pseudolanguage_vs_python_function4.jpg" width="500">

# %%
def calc_sum(x, y):
    return x + y

result = calc_sum(1, 2)
print(result)

# %% [markdown]
# ## 実習
# * 以下のコードセルに，次の擬似言語で記述したコードと同じ処理をするPythonコードを作成し，実行せよ
#
#   <img src="./fig/pseudolanguage_vs_python_function5.jpg" width="350">

# %% [markdown]
# # 探索アルゴリズム
# * 詳細な説明は省略するが，以下のコードで各探索アルゴリズムを実現できる
# * なお，本講義において，以下のコードの理解は必須とはしない

# %% [markdown]
# ## 線形探索アルゴリズム
# * 線形探索アルゴリズムを関数「`linear_search`」として定義する
# * `linear_search`関数には，探索対象のリスト（`data`）と探索する値（`x`）の2つを引数として渡す

# %%
def linear_search(data, x):
    for i in range(len(data)):
        if data[i] == x:
            return i
    return -1

result = linear_search([6, 5, 9, 2, 4, 1], 2)
print(result)

# %% [markdown]
# ## 二分探索アルゴリズム
# * 二分探索アルゴリズムを関数「`binary_search`」として定義する
# * `binary_search`関数には，探索対象のリスト（`data`）と探索する値（`x`）の2つを引数として渡す

# %%
def binary_search(data, x):
    h = 0
    t = len(data) - 1
    while h <= t:
        m = (h + t) // 2
        if data[m] == x:
            return m
        elif data[m] < x:
            h = m + 1
        else:
            t = m - 1
    return -1

result = binary_search([1, 2, 4, 5, 6, 9], 2)
print(result)

# %% [markdown]
# # ソートアルゴリズム
# * 詳細な説明は省略するが，以下のコードで各ソートアルゴリズムを実現できる
# * なお，本講義において，以下のコードの理解は必須とはしない

# %% [markdown]
# ## バブルソート
# * ソート対象のリストを引数とした`bubble_sort`関数を定義する
# * `bubble_sort`関数はソート後のリストを戻り値としている

# %%
def bubble_sort(data):
    n = len(data)
    for i in range(0, n-1):
        for j in range(n-1, i, -1):
            if data[j-1] > data[j]:
                data[j], data[j-1] = data[j-1], data[j]
    return data

result = bubble_sort([6, 5, 9, 2, 4])
print(result)

# %% [markdown]
# ## クイックソート
# * ソート対象のリストを引数とした`bubble_sort`関数を定義する
# * `bubble_sort`関数はソート後のリストを戻り値としている

# %%
def quick_sort(data):
    left_set = []
    right_set = []

    if len(data) <= 1:
        return data

    pivot = data.pop()

    for i in range(len(data)):
        if data[i] <= pivot:
            left_set.append(data[i])
        else:
            right_set.append(data[i])

    left_set = quick_sort(left_set)
    right_set = quick_sort(right_set)
    return left_set + [pivot] + right_set

result = quick_sort([6, 5, 9, 2, 4])
print(result)
